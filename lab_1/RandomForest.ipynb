# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image
import graphviz
from random import randint

from sklearn.tree import export_graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV, train_test_split

# %% [markdown]
# ### Reading [Water Quality](https://www.kaggle.com/datasets/mssmartypants/water-quality) dataset

# %% [markdown]
# INITIALIZE DF (load data)

# %%
data_df = pd.read_csv('waterQuality1.csv') #read csv
data_df.head() #show first 5 rows of dataset
# Out:
#    aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65    9.08     0.04    2.85    0.007        0.35      0.83    0.17
# 1       2.32   21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01   14.02     0.04    0.58    0.008        4.24      0.53    0.02
# 3       1.36   11.33     0.04    2.96    0.001        7.23      0.03    1.66
# 4       0.92   24.33     0.03    0.20    0.006        2.67      0.69    0.57
#
#    flouride  bacteria  ...   lead  nitrates  nitrites  mercury  perchlorate  \
# 0      0.05      0.20  ...  0.054     16.08      1.13    0.007        37.75
# 1      0.90      0.65  ...  0.100      2.01      1.93    0.003        32.26
# 2      0.99      0.05  ...  0.078     14.16      1.11    0.006        50.28
# 3      1.08      0.71  ...  0.016      1.41      1.29    0.004         9.12
# 4      0.61      0.13  ...  0.117      6.74      1.11    0.003        16.90
#
#    radium  selenium  silver  uranium  is_safe
# 0    6.78      0.08    0.34     0.02        1
# 1    3.21      0.08    0.27     0.05        1
# 2    7.07      0.07    0.44     0.01        0
# 3    1.72      0.02    0.45     0.05        1
# 4    2.41      0.02    0.06     0.02        1
#
# [5 rows x 21 columns]

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7999 entries, 0 to 7998
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   aluminium    7999 non-null   float64
#  1   ammonia      7999 non-null   object
#  2   arsenic      7999 non-null   float64
#  3   barium       7999 non-null   float64
#  4   cadmium      7999 non-null   float64
#  5   chloramine   7999 non-null   float64
#  6   chromium     7999 non-null   float64
#  7   copper       7999 non-null   float64
#  8   flouride     7999 non-null   float64
#  9   bacteria     7999 non-null   float64
#  10  viruses      7999 non-null   float64
#  11  lead         7999 non-null   float64
#  12  nitrates     7999 non-null   float64
#  13  nitrites     7999 non-null   float64
#  14  mercury      7999 non-null   float64
#  15  perchlorate  7999 non-null   float64
#  16  radium       7999 non-null   float64
#  17  selenium     7999 non-null   float64
#  18  silver       7999 non-null   float64
#  19  uranium      7999 non-null   float64
#  20  is_safe      7999 non-null   object
# dtypes: float64(19), object(2)
# memory usage: 1.3+ MB

# %% [markdown]
# #### Preprocessing Data of Water Quality

# %%
data_df.isnull().sum()
# Out:
# aluminium      0
# ammonia        0
# arsenic        0
# barium         0
# cadmium        0
# chloramine     0
# chromium       0
# copper         0
# flouride       0
# bacteria       0
# viruses        0
# lead           0
# nitrates       0
# nitrites       0
# mercury        0
# perchlorate    0
# radium         0
# selenium       0
# silver         0
# uranium        0
# is_safe        0
# dtype: int64

# %%
# Знайдемо рядки зі значенням "#NUM!" і видалимо їх з набору даних
data_df = data_df[data_df != '#NUM!'].dropna()
data_df.shape
# Out:
# (7996, 21)

# %%
# Змінюємо тип даних стовпців 'ammonia' та 'is_safe' на стандартний для всіх float64
data_df['ammonia'] = data_df['ammonia'].astype(float)
data_df['is_safe'] = data_df['is_safe'].astype(float)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7996 entries, 0 to 7998
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   aluminium    7996 non-null   float64
#  1   ammonia      7996 non-null   float64
#  2   arsenic      7996 non-null   float64
#  3   barium       7996 non-null   float64
#  4   cadmium      7996 non-null   float64
#  5   chloramine   7996 non-null   float64
#  6   chromium     7996 non-null   float64
#  7   copper       7996 non-null   float64
#  8   flouride     7996 non-null   float64
#  9   bacteria     7996 non-null   float64
#  10  viruses      7996 non-null   float64
#  11  lead         7996 non-null   float64
#  12  nitrates     7996 non-null   float64
#  13  nitrites     7996 non-null   float64
#  14  mercury      7996 non-null   float64
#  15  perchlorate  7996 non-null   float64
#  16  radium       7996 non-null   float64
#  17  selenium     7996 non-null   float64
#  18  silver       7996 non-null   float64
#  19  uranium      7996 non-null   float64
#  20  is_safe      7996 non-null   float64
# dtypes: float64(21)
# memory usage: 1.3 MB

# %% [markdown]
# #### Split data

# %%
X = data_df.drop(['is_safe'], axis = 1)
y = data_df['is_safe']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
X.head()
# Out:
#    aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65     9.08     0.04    2.85    0.007        0.35      0.83    0.17
# 1       2.32    21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01    14.02     0.04    0.58    0.008        4.24      0.53    0.02
# 3       1.36    11.33     0.04    2.96    0.001        7.23      0.03    1.66
# 4       0.92    24.33     0.03    0.20    0.006        2.67      0.69    0.57
#
#    flouride  bacteria  viruses   lead  nitrates  nitrites  mercury  \
# 0      0.05      0.20    0.000  0.054     16.08      1.13    0.007
# 1      0.90      0.65    0.650  0.100      2.01      1.93    0.003
# 2      0.99      0.05    0.003  0.078     14.16      1.11    0.006
# 3      1.08      0.71    0.710  0.016      1.41      1.29    0.004
# 4      0.61      0.13    0.001  0.117      6.74      1.11    0.003
#
#    perchlorate  radium  selenium  silver  uranium
# 0        37.75    6.78      0.08    0.34     0.02
# 1        32.26    3.21      0.08    0.27     0.05
# 2        50.28    7.07      0.07    0.44     0.01
# 3         9.12    1.72      0.02    0.45     0.05
# 4        16.90    2.41      0.02    0.06     0.02

# %% [markdown]
# #### Standardize the Variables

# %%
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
scaled_X_train = scaler.transform(X_train) 
scaled_X_test = scaler.transform(X_test)

# %% [markdown]
# #### Random forest model

# %%
random_forest = RandomForestClassifier(max_depth=2, random_state=0, n_estimators=200)
random_forest.fit(scaled_X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=2, n_estimators=200, random_state=0)

# %%
pred = random_forest.predict(scaled_X_test)

# %% [markdown]
# #### Evaluation

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[1420    0]
#  [ 180    0]]

# %% [markdown]
# * LeftTop - кількість True Negatives (TN). Вказує на кількість прикладів, які були правильно класифіковані як негативні (клас 0). <br>
#
# * RightTop - кількість False Positives (FP). Вказує на кількість прикладів, які були неправильно класифіковані як позитивні (клас 1), коли насправді вони належать до класу 0. <br>
#
# * LeftDown - кількість False Negatives (FN). Вказує на кількість прикладів, які були неправильно класифіковані як негативні (клас 0), коли насправді вони належать до класу 1. <br>
#
# * RightDown - кількість True Positives (TP). Вказує на кількість прикладів, які були правильно класифіковані як позитивні (клас 1). <br>
#
# На основі отриманих даних можемо обчислити різні метрики класифікації, такі як точність, чутливість, специфічність, F1-показник та інші, щоб оцінити якість нашої моделі класифікації.

# %%
print(classification_report(y_test,pred, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.89      1.00      0.94      1420
#          1.0       1.00      0.00      0.00       180
#
#     accuracy                           0.89      1600
#    macro avg       0.94      0.50      0.47      1600
# weighted avg       0.90      0.89      0.83      1600

# %% [markdown]
# Precision (точність):
# * при 0.0 - %TP, вказує на низьку\високу точність, модель має низьку\високу кількість хибно позитивних. <br>
# * при 1.0 - %TP, вказує на те, що модель має менше\більше хибно позитивних для цього класу. <br>
#
# Recall (чутливість):
# * при 0.0 - %TP, вказує на низьку\високу чутливість моделі для класу 0.0.
# * при 1.0 - %TP, вказує на меншу\більшу чутливість для класу 1.0.
#
# F1-Score (F1-показник) є гармонічним середнім точності та чутливості:
# * при 0.0 - вказує на погану\добру якість моделі для класу 0.0.
# * при 1.0 - вказує на те, що модель може бути менш\більш ефективною у класифікації цього класу.
#
# Support: кількість прикладів у кожному класі у тестовому наборі даних.
#
# Accuracy (точність): загальна точність моделі, яка вказує на те, наскільки часто модель правильно класифікує приклади.
#
# Macro Avg: середнє значення метрик для всіх класів. В нашому випадку, середнє значення точності, чутливості і F1-показника для всіх класів.
#
# Weighted Avg: середнє значення метрик для всіх класів, де кожен клас зважується на підтримку (кількість прикладів) відповідного класу.

# %%
print(accuracy_score(y_test,pred)) #відсоток правильних класифікацій
# Out:
# 0.8875

# %% [markdown]
# #### Choosing parameter

# %% [markdown]
# Аналіз впливу максимальної глибини дерева на помилки моделі Random Forest та визначення оптимальної глибини для даної задачі.

# %% [markdown]
# * n_estimators -- кількість дерев рішень у лісі. Збільшення цього гіперпараметра загалом покращує продуктивність моделі, але також збільшує обчислювальні витрати на навчання та прогнозування.
# * max_depth -- максимальна глибина кожного дерева рішень у лісі. Встановлення більшого значення для max_depth може призвести до overfitting, тоді як встановлення занадто низького значення може призвести до underfitting.
# * random_state -- початковий стан для відтворюваності результатів.

# %%
error_rate = []

for i in range(1,30):
    random_forest = RandomForestClassifier(max_depth=i, random_state=0, n_estimators=200)
    random_forest.fit(scaled_X_train, y_train)
    pred_i = random_forest.predict(scaled_X_test)
    error_rate.append(np.mean(pred_i != y_test)) #Розраховується середнє значення помилки класифікації для поточної максимальної глибини

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,30), error_rate, marker='o', markersize=10)
plt.title('Error Rate vs. Max depth')
plt.xlabel('Max Depth')
plt.ylabel('Error Rate')
plt.grid()

# %% [markdown]
# По горизонталі відображаються значення максимальної глибини, а по вертикалі - середня помилка класифікації для кожної максимальної глибини.

# %% [markdown]
# Тепер виконаємо аналіз впливу кількості дерев в ансамблі випадкового лісу на помилки моделі та визначимо оптимальну кількість дерев для даної задачі.

# %%
error_rate = []

for i in range(1,500):
    random_forest = RandomForestClassifier(max_depth=2, random_state=0, n_estimators=i)
    random_forest.fit(scaled_X_train, y_train)
    pred_i = random_forest.predict(scaled_X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,500), error_rate, marker='o', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
plt.grid()

# %%
random_forest = RandomForestClassifier()
random_forest.fit(scaled_X_train, y_train)
pred = random_forest.predict(scaled_X_test)
param_dist = {'n_estimators': randint(50,500),
              'max_depth': randint(1,20)}
rand_search = RandomizedSearchCV(random_forest, 
                                 param_distributions = param_dist, 
                                 n_iter=5, 
                                 cv=5)
print('Best hyperparameters:',  rand_search)

print(confusion_matrix(y_test,pred))
print()
print(classification_report(y_test,pred))
# Out:
# Best hyperparameters: RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=5,
#                    param_distributions={'max_depth': 1, 'n_estimators': 194})
# [[1406   14]
#  [  57  123]]
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.98      1420
#          1.0       0.90      0.68      0.78       180
#
#     accuracy                           0.96      1600
#    macro avg       0.93      0.84      0.88      1600
# weighted avg       0.95      0.96      0.95      1600

# %% [markdown]
# ##### Для матриці:
# * LeftTop - кількість True Negatives (TN). Вказує на кількість прикладів, які були правильно класифіковані як негативні (клас 0). <br>
#
# * RightTop - кількість False Positives (FP). Вказує на кількість прикладів, які були неправильно класифіковані як позитивні (клас 1), коли насправді вони належать до класу 0. <br>
#
# * LeftDown - кількість False Negatives (FN). Вказує на кількість прикладів, які були неправильно класифіковані як негативні (клас 0), коли насправді вони належать до класу 1. <br>
#
# * RightDown - кількість True Positives (TP). Вказує на кількість прикладів, які були правильно класифіковані як позитивні (клас 1). <br>
#
# На основі отриманих даних можемо обчислити різні метрики класифікації, такі як точність, чутливість, специфічність, F1-показник та інші, щоб оцінити якість нашої моделі класифікації.
#
# ##### Для звіту:
#
# Precision (точність):
# * при 0.0 - %TP, вказує на низьку\високу точність, модель має низьку\високу кількість хибно позитивних. <br>
# * при 1.0 - %TP, вказує на те, що модель має менше\більше хибно позитивних для цього класу. <br>
#
# Recall (чутливість):
# * при 0.0 - %TP, вказує на низьку\високу чутливість моделі для класу 0.0.
# * при 1.0 - %TP, вказує на меншу\більшу чутливість для класу 1.0.
#
# F1-Score (F1-показник) є гармонічним середнім точності та чутливості:
# * при 0.0 - вказує на погану\добру якість моделі для класу 0.0.
# * при 1.0 - вказує на те, що модель може бути менш\більш ефективною у класифікації цього класу.
#
# Support: кількість прикладів у кожному класі у тестовому наборі даних.
#
# Accuracy (точність): загальна точність моделі, яка вказує на те, наскільки часто модель правильно класифікує приклади.
#
# Macro Avg: середнє значення метрик для всіх класів. В нашому випадку, середнє значення точності, чутливості і F1-показника для всіх класів.
#
# Weighted Avg: середнє значення метрик для всіх класів, де кожен клас зважується на підтримку (кількість прикладів) відповідного класу.

# %% [markdown]
# #### Graphical representation of a tree

# %% [markdown]
# Тепер виведемо графічне представлення дерева, візуалізувавши декілька дерев (3), які входять до складу моделі випадкового лісу, щоб краще зрозуміти їхню структуру та рішення, які вони приймають:

# %%
for i in range(3):
    tree = random_forest.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=X_train.columns,  
                               filled=True,  
                               max_depth=2, 
                               impurity=False, 
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %% [markdown]
# **Value:** розділяє дані на 2 класи.
